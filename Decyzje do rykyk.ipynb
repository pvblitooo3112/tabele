# %% [markdown]
# | Scenariusz / rodzaj ryzyka | Decyzja GPT-5 mini | Decyzja GPT-5 nano | Decyzja człowieka - eksperta z banku |
# | :--- | :--- | :--- | :--- |
# | **ryzyko kredytowe** | Wdrożę natychmiastowy cykl miesięcznego monitoringu i scenariuszy stresowych dla 12 kluczowych ryzyk, wprowadzając jednocześnie pilotażowy program „Kontrolowany Wzrost – Kredyty Rozwojowe” z limitami, wyższym cenieniem ryzyka i obowiązkowymi gwarancjami oraz mechanizmami eskalacji do Zarządu i Rady Nadzorczej. | w odpowiedzi na rosnące ryzyko kredytowe i możliwą koncentrację ekspozycji ograniczymy nowe kredyty w segmentach wysokiego ryzyka, podniesiemy rezerwy celowe, wzmocnimy zabezpieczenia oraz monitorowanie portfela, aby utrzymać akceptowalny poziom ryzyka i stabilność banku. | Bank powinien zatwierdzić obecną politykę kredytową pod warunkiem pozytywnego przejścia zdefiniowanych stress-testów ze szczególnym naciskiem na odporność kapitałową przy szoku w branży rolniczej. |
# | **ryzyko EKZH** | Wprowadzam natychmiastowy program stres testów EKZH zgodny z Rekomendacją S (szoki LtV i stóp: −10/−20/−30% wartości zabezpieczeń i +200/+400 bp stóp) oraz tymczasowe zaostrzenie polityki LtV i ceny ryzyka dla nowych EKZH, uruchamiając równocześnie bufor rezerwowy i plan działań naprawczych (monitoring miesięczny, ograniczenia koncentracji, program restrukturyzacji) do czasu uzyskania rezultatów testów i akceptacji Rady Nadzorczej. | ograniczymy ekspozycje EKZH poprzez zaostrzenie kryteriów kredytowych i zabezpieczeń, ograniczenie nowych kredytów w ryzykownych segmentach, zwiększymy rezerwy celowe i wzmocnimy monitoring oraz dywersyfikację portfela, aby utrzymać akceptowalny poziom jakości portfela i kapitałowy. | Bank powinien wyliczyć i zacząć raportowanie łącznej kwoty ekspozycji z portfela hipotecznego, która w warunkach zadanego szoku stopy procentowej stanie się niespłacalna (przekroczy graniczny wskaźnik DStI > 65%), w celu utworzenia adekwatnego bufora kapitałowego. |
# | **ryzyko DEK** | Wprowadzam natychmiastowy cykl testów Rekomendacji T dla DEK (DtI +200/+400 pb, scenariusze przekwalifikowań 5–20%, koncentracja RKK 3/T11), zaostrzam kryteria DtI przy nowych udzielanych DEK, uruchamiam miesięczny KRI monitoring i tworzę bufor rezerwowy (tymczasowy) dla portfela detalicznego, jednocześnie wdrażając proaktywne programy restrukturyzacji i wykorzystanie poręczeń publicznych. | ograniczymy ekspozycje DEK poprzez zaostrzenie kryteriów kredytowych i zabezpieczeń, podniesienie rezerw celowych, oraz przyspieszenie dywersyfikacji portfela, aby utrzymać akceptowalny poziom jakości portfela i kapitału. | Bank powinien ocenić adekwatność kapitałową i zdecydować, czy obecne fundusze własne Banku są wystarczające, by pokryć potencjalne straty z portfela detalicznego (DEK) w warunkach szoku stóp procentowych. |
# | **ryzyko koncentracji** | Wprowadzam natychmiast obowiązkowe wykonanie testów RKK 1..RKK 10 oraz T11 na aktualnych danych, ustanawiam twardy limit udziału jednej branży w portfelu (alarm 30% / limit 35%), uruchamiam miesięczne raportowanie koncentracji do Zarządu i komitetu ryzyka oraz wprowadzam natychmiastowe ograniczenia akcji kredytowej w sektorach przekraczających limit alarmowy.<br><br>W związku z identyfikacją Rolnictwa jako branży o największym i rosnącym udziale w portfelu (prognozowany wzrost do 57% udziału w 2025 r., tj. ok. 226 mln zł), zarządzam natychmiastowe wykonanie symulacji kapitałowej według scenariusza TI, aby potwierdzić bezpieczeństwo Banku. | Ograniczymy ryzyko koncentracji poprzez natychmiastowe zaostrzenie limitów i polityk koncentracyjnych, wzmocnienie zabezpieczeń, zwiększenie rezerw i przyspieszenie dywersyfikacji portfela, aby utrzymać akceptowalny poziom jakości portfela i kapitału. | Bank powinien przeprowadzić symulacje Testu Scenariuszowego TI z ukierunkowaniem na branżę rolniczą jako kluczowy czynnik ryzyka koncentracji |
# | **ryzyko rynkowe (walutowe)** | Natychmiast zlecę wykonanie pełnych testów scenariuszy walutowych (spadek PLN −30% / 12 mies. + interakcje płynności i kredytowe), tymczasowo obniżę limit pozycji walutowej do 0,5% kapitału, zamknę i zabezpieczę wszystkie materialne otwarte pozycje FX hedgingiem z Bankiem Zrzeszającym oraz wprowadzę zakaz nowych kredytów walutowych bez dowodu przychodów walutowych — równocześnie wdrażając stały monitoring KRI i plan kapitałowo płynnościowy. | Zoptymalizujemy ryzyko walutowe poprzez ograniczenie otwartych pozycji FX, wzmocnienie hedgingu, zwiększenie limitów ryzyka FX i rezerw, oraz wzmocnienie zarządzania portfelem walutowym, aby zminimalizować wpływ zmian kursów na wynik i kapitał banku. | Bank powinien ustalić maksymalny dopuszczalny limit Otwartej Pozycji Walutowej (Intraday oraz Overnight), który gwarantuje, że nawet w przypadku gwałtownego osłabienia złotego (szok o 30%), Bank nie przekroczy regulacyjnych norm koncentracji ani nie poniesie straty przewyższającej jego apetyt na ryzyko. |
# | **ryzyko operacyjne** | Uruchamiam wymagany plan testów wykonania z parametrami wykonawczymi (liczby transakcji, poziome odpływów, KPI), harmonogramem ćwiczeń BCP i szablon raportu po teście (wyniki + rekomendacje techniczne i administracyjne) do zatwierdzenia przez Zarząd. | Uruchamiam natychmiastowy zestaw testów warunków skrajnych operacyjnych RO-I do RO-4, wdrażam zaktualizowany plan ciągłości działania i DR, wzmacniam kontrolę wewnętrzną oraz program szkoleniowy, a także wprowadzam natychmiastowe działania naprawcze dla kluczowych procesów i dostawców, aby ograniczyć straty operacyjne, ryzyko reputacyjne i wpływ na wyniki Banku. | Bank powinien podjąć decyzje o wdrożeniu i sfinansowaniu Planu Odtwarzania Awaryjnego, który zapewni, że w przypadku wystąpienia któregokolwiek ze zidentyfikowanych zdarzeń krytycznych, Bank będzie w stanie przywrócić kluczowe procesy (dostęp do środków, obsługa transakcji) w akceptowalnym czasie (np. krótszym niż 2 doby z testu RO-2), chroniąc tym samym instytucję przed upadkiem zidentyfikowanym w teście odwrotnym. |
# | **ryzyko stopy procentowej w portfelu bankowym** | wykonam szczegółowy plan testów krok-po-kroku (parametry Bucketów, założenia DtI, listy najbardziej rygorystycznych segmentów i kalkulacje wpływu na TCR) i nadzorujący wzór raportu ALCO / zarządzenia i wyniki rekomendacji działań naprawczych. | Na podstawie wyników testów warunków skrajnych IRRBB Bank natychmiast ograniczy ekspozycje EKZH i duże zaangażowania przekraczające 10% kapitału Tier I, zwiększy rezerwy celowe dla ekspozycji zagrożonych oraz dostosuje limity LtV/DtI i poziom płynności, aby utrzymać akceptowalny poziom kapitału i wyników finansowych. | Bank powinien ustanowić sztywy limitu bezpieczeństwa dla spadku wartości ekonomicznej kapitału (EVE) |
# | **ryzyko płynności i finansowania** | uruchamiam natychmiastowy plan awaryjny płynności (CFTP), zwiększam HQLA do poziomu zabezpieczającego 30 dniowy horyzont przeżycia, wstrzymuję nowe duże zaangażowania i nakazuję pilne przeprowadzenie wymienionych testów stresowych (LCR, NSFR, odpływ 20%, T11, RO 2 i scenariusz cyfrowego bank run), równocześnie przygotowując plan kapitałowy i program proaktywnej restrukturyzacji kredytów, aby zapobiec dalszemu pogorszeniu jakości portfela. | Uruchamiam natychmiast zestaw testów warunków skrajnych płynności (LCR i NSFR) oraz scenariusze depozytowego i funduszowego stresu, aktualizuję plan awaryjny płynności (BCP/FS) i wprowadzam natychmiastowe działania naprawcze w zakresie źródeł finansowania oraz limitów płynności, aby utrzymać akceptowalny poziom LCR/NSFR i zapobiec niedoborom finansowania. | Bank powinien określić pozycję do przetrwania i dostosowanie wielkości Bufora Płynnościowego tak, aby Bank był w stanie obsługiwać wszystkie zlecone przez klientów wypłaty (w tym masowe wycofania przez bankowość internetową) przez określony czas bez konieczności wyprzedaży aktywów ze stratą lub sięgania po pomoc publiczną. |
# | **ryzyko nadmiernej dźwigni finansowej** | natychmiast zlecam przeprowadzenie pełnego pakietu testów stresowych związanych z dźwignią (w tym Test ND opisany w materiałach, Test Kap ( 2% funduszy), T11, RK 2, RK 6, RKK 1 oraz scenariuszy LCR/NSFR/odpływu depozytów 20%) i równocześnie wprowadzam moratorium na nowe duże zaangażowania (>10% Tier I) do czasu wdrożenia rekomendowanego planu kapitałowego i zabezpieczeń (bufor kapitałowy + plan awaryjny płynności). | Uruchamiam natychmiast testy warunków skrajnych nad nadmierną dźwignią finansową, oceniam wpływ na kapitał i wskaźniki, a w razie przekroczenia limitów natychmiast podejmuję działania naprawcze: ograniczenie dywidend, zwiększenie kapitału i redukcję ekspozycji, aby przywrócić bezpieczny poziom dźwigni i stabilność banku. | Bank powinien przeprowadzić test polegający na ocenie wpływu wystąpienia straty finansowej na wskaźnik dźwigni finansowej na skutek zmiany poziomu funduszy własnych |
# | **ryzyko biznesowe** | natychmiast ograniczam koncentrację sektora rolnego poprzez obniżenie wewnętrznych limitów sektorowych i limitów pojedynczych dużych ekspozycji, jednocześnie uruchamiając kontrolowany program wzrostu finansowania rolniczego z zaostrzonymi zabezpieczeniami, wyższą ceną ryzyka i obligatoryjnym monitoringiem stres testowym. | Natychmiast uruchamiam testy RBIZ 1–RBIZ 3 dotyczące ryzyka biznesowego i w przypadku potwierdzenia istotnego wpływu na wynik i adekwatność kapitałową, wprowadzę natychmiast ograniczenia ekspozycji, zwiększę rezerwy/odpisy oraz zaktualizuję plan ekonomiczno-finansowy i politykę zarządzania ryzykiem biznesowym | Bank powinien podjąć decyzję o weryfikacji i ewentualnej korekcie Planu Finansowego, tak aby zapewnić, że nawet w przypadku realizacji pesymistycznego scenariusza Bank utrzyma łączy współczynnik kapitałowy pow. 12,50% |
# | **ryzyko kapitałowe** | natychmiast wprowadzam kwartalny cykl testów kapitałowych T11 i odwrotnych wraz z obowiązkiem automatycznego uruchomienia planu kapitałowego (retencja zysków i ograniczenie akcji kredytowej) przy zbliżeniu TCR do 12,5%, jednocześnie zezwalając na kontrolowany wzrost ekspozycji w wybranych segmentach tylko w ramach programu „Ryzyko Celowane z Podziałem Ryzyka” z dodatkowymi zabezpieczeniami i wewnętrznym add on kapitałowym. | natychmiast uruchamiam testy RK-1–RK-6 dotyczące ryzyka kapitałowego, oszacuję ich wpływ na wynik i adekwatność kapitałową portfela (zwłaszcza EKZH) iw przypadku przekroczeń natychmiast wprowadzę działania ograniczające ryzyko, podniosę rezerwy/odpisy | Bank powinien zatwierdzić Plan Kapitałowy (ICAAP), w tym decyzję o podziale zysku (wypłata dywidendy vs. zatrzymanie zysku), tak aby zapewnić, że Bank posiada wystarczającą nadwyżkę kapitałową (bufor) do pokrycia ewentualnych strat i wzrostu wymogów (o min. 2% wskazane w teście) bez naruszania minimów nadzorczych. |
