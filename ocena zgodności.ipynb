# %% [markdown]
# | Scenariusz | Ocena zgodności decyzji GPT-5 mini i nano | Ocena zgodności między GPT-5 mini i ekspertem człowiekiem | Ocena zgodności między GPT-5 nano i ekspertem człowiekiem | Ocena zgodności wszystkich decyzji |
# | :--- | :---: | :---: | :---: | :--- |
# | **ryzyko kredytowe** | średnia | średnia | wysoka | Ekspert oczekuje potwierdzenia odporności na scenariusz szokowy przeprowadzając testy, model mini wdraża restrykcje, a nano przeprowadza monitoring |
# | **ryzyko EKZH** | wysoka | wysoka | wysoka | Jednogłośna decyzja wszystkich: zwiększamy bufor kapitałowy |
# | **ryzyko DEK** | wysoka | wysoka | wysoka | Modele i ekspert są zdania, że fundusze własne mogą być niewystarczające i trzeba utworzyć dodatkowe rezerwy |
# | **ryzyko koncentracji** | wysoka | wysoka | średnia | Ekspert identyfikuje ryzyko nadmiernej koncentracji w rolnictwie przez testowanie, na co GPT-5 mini reaguje adekwatnym, twardym limitem portfelowym, tak samo model nano decyduje się na zaostrzanie limitów |
# | **ryzyko rynkowe (walutowe)** | wysoka | wysoka | wysoka | Jednogłośna decyzja i zgodność: dokonać bezpiecznego zamknięcia pozycji walutowej do przetrwania gwałtownych deprecjacji złotego |
# | **ryzyko operacyjne** | średnia | niska | wysoka | Ekspert i GPT-5 nano zgodnie priorytetyzują realne bezpieczeństwo operacyjne, podczas gdy GPT-5 mini pozostaje w trybie planowania testów. |
# | **ryzyko stopy procentowej w portfelu bankowym** | niska | niska | wysoka | Ekspert definiuje strategiczny cel (limit EVE), GPT-5 nano ogranicza ekspozycje, podnosi rezerwy i dokonuje korekty LtV, podczas gdy GPT-5 mini nie podejmuje działań operacyjnych, ograniczając się do monitoringu. |
# | **ryzyko płynności i finansowania** | wysoka | wysoka | wysoka | Jednogłośna decyzja wszystkich: zwiększamy bufor płynnościowy |
# | **ryzyko nadmiernej dźwigni finansowej** | wysoka | wysoka | wysoka | Wszystkie podmioty zgodnie identyfikują konieczność powiązania wyników testów z natychmiastowymi ograniczeniami kapitałowymi lub kredytowymi |
# | **ryzyko biznesowe** | średnia | średnia | wysoka | GPT-5 mini podejmuje agresywną decyzję sektorową przez natychmiastowe ograniczenie koncentracji w rolnictwie, podczas gdy Ekspert i GPT-5 nano preferują systemowe zarządzanie poprzez weryfikację Planu Finansowego Banku oraz uruchomienie testów |
# | **ryzyko kapitałowe** | wysoka | wysoka | wysoka | Pełna zgodność co do wykorzystania podziału zysku jako głównego narzędzia zapewnienia adekwatności kapitałowej powyżej minimów nadzorczych. |
